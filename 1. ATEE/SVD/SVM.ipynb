# %%
import numpy as np
W1 = 1
b = -9
W0 = 0.4

(x1,x2) = (1,3)
(x3,x4) = (5,7)
(x5,x6) = (8,7)

P1 = np.array([x1,x2])
P2 = np.array([x3,x4])
P3 = np.array([x5,x6])

w = np.array([W0,W1])

P1_calc = np.matmul(w.T,P1) + b
P2_calc = np.matmul(w.T,P2) + b
P3_calc = np.matmul(w.T,P3) + b

calc = (P1_calc,P2_calc,P3_calc)
print(calc)

d = np.matmul(w.T, P1) + b
# Out:
# (-5.6, 0.0, 1.1999999999999993)
