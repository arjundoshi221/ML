# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
import seaborn as sns
sns.set()

# %%
from sklearn.svm import SVC
svm = SVC(kernel='poly')

df = pd.read_csv(r"D:\Arjun 2\Coding Files-Arjun\Computer Science\College\IntroToML\SVM\diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_y = df.iloc[:,-1]
df_y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 103    0
# 104    0
# 105    0
# 106    0
# 107    0
# Name: Outcome, Length: 108, dtype: int64

# %%
df_x = df.iloc[:,:-1]
df_x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 103            1       81             72             18       40  26.6
# 104            2       85             65              0        0  39.6
# 105            1      126             56             29      152  28.7
# 106            1       96            122              0        0  22.4
# 107            4      144             58             28      140  29.5
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 103                     0.283   24
# 104                     0.930   27
# 105                     0.801   21
# 106                     0.207   27
# 107                     0.287   37
#
# [108 rows x 8 columns]

# %%
x_train, X_test, Y_train, y_test = train_test_split(df_x,df_y)

# %%
svm1 = svm.fit(x_train,Y_train)
y_pred = svm1.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[16,  1],
#        [ 4,  6]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8148148148148148

# %%
len(svm.support_vectors_)
# Out:
# 54
